# %% [markdown]
# # WEB SCRAPING -ASSIGNMENT-4

# %%
# !pip install selenium

# %%
#importing libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup


#importing selenium webdriver
from selenium import webdriver

#Importing required exception which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

#import regex
import re
from selenium.webdriver.common.by import By

import time

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
Vedios_Rank=[]
Vedios_Name=[]
Vedios_Artist=[]
Upload_Date=[]
Vedios_Views=[]

# %%
Vedios_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
for i in Vedios_tags:
    Rank=i.text
    Vedios_Rank.append(Rank)
    
Vedios_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
for i in Vedios_tags:
    Name=i.text
    Vedios_Name.append(Name)
    
Vedios_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
for i in Vedios_tags:
    Artist=i.text
    Vedios_Artist.append(Artist)
    
Upload_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
for i in Upload_tags:
    Date=i.text
    Upload_Date.append(Date)
    
    
Vedios_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')
for i in Vedios_tags:
    Views=i.text
    Vedios_Views.append(Views)

# %%
print(len(Vedios_Rank),len(Vedios_Name),len(Vedios_Artist),len(Upload_Date),len(Vedios_Views))
# Out:
# 30 30 30 30 30

# %%
import pandas as pd
df=pd.DataFrame({'Rank':Vedios_Rank,'Name':Vedios_Name,'Artist':Vedios_Artist,'Upload_Date':Upload_Date,'Views':Vedios_Views})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                     "Axel F"[35]
# ...

# %% [markdown]
# 2. Scrape the details teamIndia’sinternationalfixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1stODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get("https://www.bcci.tv/")

# %%
searchimg=driver.find_element(By.XPATH,"/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a")
searchimg.click()

# %%
Allformat=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[1]")
Allformat.click()

# %%
ODIFixture=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[2]/div[3]")
ODIFixture.click()

# %%
Match_Title=[]
INT_Series=[]
Match_Place=[]
Match_Date=[]
Match_Time=[]

# %%
Match_tags=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
for i in Match_tags:
    Title=i.text
    Match_Title.append(Title)
    
INT_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
for i in INT_tags:
    Series=i.text
    INT_Series.append(Series)
    
Match_tags=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
for i in Match_tags:
    Place=i.text
    Match_Place.append(Place) 
    
Match_tags=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
for i in Match_tags:
    Date=i.text
    Match_Date.append(Date)    
    
Match_tags=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
for i in Match_tags:
    Time=i.text
    Match_Time.append(Time)

# %%
print(len(Match_Title),len(INT_Series),len(Match_Place),len(Match_Date),len(Match_Time))
# Out:
# 3 3 3 3 3

# %%
import pandas as pd
df=pd.DataFrame({'Title':Match_Title,'Series':INT_Series,'Place':Match_Place,'Date':Match_Date,'Time':Match_Time})
df
# Out:
#        Title                                      Series  \
# 0  1st ODI -  AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 1  2nd ODI -  AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 2  3rd ODI -  AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
#
#                                                Place         Date         Time
# 0                                  Wankhede Stadium,  17 MAR 2023  1:30 PM IST
# 1  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadium,  19 MAR 2023  1:30 PM IST
# 2                            MA Chidambaram Stadium,  22 MAR 2023  1:30 PM IST

# %% [markdown]
# 3. Scrape the details of State-wise GDP ofIndia fromstatisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/ ")

# %%
searchEconomy=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")
searchEconomy.click()

# %%
searchEconomyindia=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
searchEconomyindia.click()

# %%
searchEconomyindiastate=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
searchEconomyindiastate.click()

# %%
GDP_Rank=[]
GDP_State=[]
GDP_GSDP18_19=[]
GDP_GSDP19_20=[]
GDP_share18_19=[]
Gross_GDPbillion=[]

# %%
GDP_tags=driver.find_elements(By.XPATH,'//td[@class="data1"]')
for i in GDP_tags[0:33]:
    Rank=i.text
    GDP_Rank.append(Rank)
    
GDP_tags=driver.find_elements(By.XPATH,'//td[@class="name"]')
for i in GDP_tags[0:33]:
    State=i.text
    GDP_State.append(State) 
    
GDP_tags=driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]')
for i in GDP_tags[0:33]:
    GSDP18_19=i.text
    GDP_GSDP18_19.append(GSDP18_19)    
    
GDP_tags=driver.find_elements(By.XPATH,'//table[@class="display dataTable"][1]/tbody/tr/td[3]')
for i in GDP_tags[0:33]:
    GSDP19_20=i.text
    GDP_GSDP19_20.append(GSDP19_20)
    
    
GDP_tags=driver.find_elements(By.XPATH,'//table[@class="display dataTable"][1]/tbody/tr/td[5]')
for i in GDP_tags[0:33]:
    share18_19=i.text
    GDP_share18_19.append(share18_19)    
    
GDP_tags=driver.find_elements(By.XPATH,'//table[@class="display dataTable"][1]/tbody/tr/td[6]')
for i in GDP_tags[0:33]:
    GDPbillion=i.text
    Gross_GDPbillion.append(GDPbillion)

# %%
print(len(GDP_Rank),len(GDP_State),len(GDP_GSDP18_19),len(GDP_GSDP19_20),len(GDP_share18_19),len(Gross_GDPbillion))
# Out:
# 33 33 33 33 33 33

# %%
import pandas as pd
df=pd.DataFrame({'Rank':GDP_Rank,'State':GDP_State,'GSDP18_19atcurrent_prices':GDP_GSDP18_19,'GSDP19_20at_current_prices':GDP_GSDP19_20,'Share18_19':GDP_share18_19,'GDP$Billion':Gross_GDPbillion})
df
# Out:
#    Rank                      State GSDP18_19atcurrent_prices  \
# 0     1                Maharashtra                 2,632,792
# 1     2                 Tamil Nadu                 1,630,208
# 2     3              Uttar Pradesh                 1,584,764
# 3     4                    Gujarat                 1,502,899
# 4     5                  Karnataka                 1,493,127
# 5     6                West Bengal                 1,089,898
# 6     7                  Rajasthan                   942,586
# 7     8             Andhra Pradesh                   862,957
# 8     9                  Telangana                   861,031
# 9    10             Madhya Pradesh                   809,592
# 10   11                     Kerala                   781,653
# 11   12                      Delhi                   774,870
# 12   13                    Haryana                   734,163
# 13   14                      Bihar                   530,363
# ...

# %% [markdown]
# 4. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get("https://github.com/")

# %%
searchmain=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
searchmain.click()

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
search.click()

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_Used=[]

# %%
Repository_tags=driver.find_elements(By.XPATH,'//div[@class="Box"][1]/div/article/h1/a')
for i in Repository_tags:
    title=i.text
    Repository_title.append(title)

# %%
Repository_title
# Out:
# ['microsoft / visual-chatgpt',
#  'togethercomputer / OpenChatKit',
#  'microsoft / visual-chatgpt',
#  'ggerganov / llama.cpp',
#  'GanymedeNil / document.ai',
#  'kaixindelele / ChatPaper',
#  'ggerganov / whisper.cpp',
#  'sindresorhus / awesome',
#  'camenduru / stable-diffusion-webui-colab',
#  'donnemartin / system-design-primer',
#  'davinci1012 / pinduoduo_backdoor_unpacker',
#  'oobabooga / text-generation-webui',
#  'termux / termux-packages',
#  'tangly1024 / NotionNext',
#  'sherlock-project / sherlock',
#  'neovim / neovim',
#  'bmaltais / kohya_ss',
#  'mckaywrigley / chatbot-ui',
#  'The-Art-of-Hacking / h4cker',
#  'CS-BAOYAN / CSSummerCamp2023',
#  'Genymobile / scrcpy',
#  'hiifeng / V2ray-for-Doprax',
#  'futantan / OpenGpt',
#  'zauberzeug / nicegui',
#  'iptv-org / iptv',
#  'yuvalsuede / ai-component-generator']

# %%
Repository_tags=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in Repository_tags:
    description=i.text
    Repository_description.append(description)

# %%
Repository_description
# Out:
# ['Official repo for the paper: Visual ChatGPT: Talking, Drawing and Editing with Visual Foundation Models',
#  "Port of Facebook's LLaMA model in C/C++",
#  '基于向量数据库与GPT3.5的通用本地知识库方案(A universal local knowledge base solution based on vector database and GPT3.5)',
#  'Use ChatGPT to summarize the arXiv papers.',
#  "Port of OpenAI's Whisper model in C/C++",
#  '😎 Awesome lists about all kinds of interesting topics',
#  'stable diffusion webui colab',
#  'Learn how to design large-scale systems. Prep for the system design interview. Includes Anki flashcards.',
#  'Samples and Unpacker of malicious backdoors and exploits developed and used by Pinduoduo',
#  'A gradio web UI for running Large Language Models like GPT-J 6B, OPT, GALACTICA, LLaMA, and Pygmalion.',
#  'A package build system for Termux.',
#  '一个使用 NextJS + Notion API 实现的，部署在 Vercel 上的静态博客系统。为Notion和所有创作者设计。',
#  '🔎 Hunt down social media accounts by username across social networks',
# ...

# %%
Contributors_tags=driver.find_elements(By.XPATH,'//div[@class="Box"][1]/div/article/div/a[2]')
for i in Contributors_tags:
    count=i.text
    Contributors_count.append(count)

# %%
Contributors_count
# Out:
# ['194',
#  '1,292',
#  '215',
#  '84',
#  '82',
#  '782',
#  '25,192',
#  '594',
#  '38,140',
#  '210',
#  '208',
#  '2,607',
#  '1,704',
#  '4,716',
#  '4,491',
#  '151',
#  '26',
#  '2,214',
#  '66',
#  '8,138',
#  '18,014',
#  '99',
#  '83',
#  '44',
#  '84']

# %%
Language_tags=driver.find_elements(By.XPATH,'//div[@class="Box"][1]/div/article/div/span/span[2]')
for i in Language_tags:
    Used=i.text
    Language_Used.append(Used)

# %%
Language_Used
# Out:
# ['Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'C',
#  'Jupyter Notebook',
#  'Python',
#  'Java',
#  'Python',
#  'Shell',
#  'JavaScript',
#  'Python',
#  'Vim Script',
#  'Python',
#  'TypeScript',
#  'Jupyter Notebook',
#  'C',
#  'Dockerfile',
#  'TypeScript',
#  'Python',
#  'JavaScript',
#  'TypeScript']

# %% [markdown]
# 5. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get(" https:/www.billboard.com/")

# %%
searchchart=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
searchchart.click()

# %%
searchview=driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
searchview.click()

# %%
Song_Name1A=[]
Artist_Name1=[]
Last_Weekrank1=[]
Peak_Rank1=[]
Week_Onboard1=[]

# %%
Song_tags=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"][1]/ul/li/h3')
for i in Song_tags:
    Name1A=i.text
    Song_Name1A.append(Name1A)
    
Artist_tags=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"][1]/ul/li[1]/span[1]')
for i in Song_tags:
    Name1=i.text
    Artist_Name1.append(Name1)
    
Last_tags=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"][1]/ul/li[4]/span')
for i in Last_tags:
    Weekrank1=i.text
    Last_Weekrank1.append(Weekrank1)
    
Peak_tags=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"][1]/ul/li[5]/span')
for i in Last_tags:
    Rank1=i.text
    Peak_Rank1.append(Rank)    

    
Week_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet"]')
for i in Last_tags:
    Onboard1=i.text
    Week_Onboard1.append(Onboard1)

# %%
df=pd.DataFrame({'Song_Name1A':Song_Name1A,'Artist_Name1':Artist_Name1,'Last_Weekrank1':Last_Weekrank1,'Peak_Rank1':Peak_Rank1,'Week_Onboard1':Week_Onboard1})
df
# Out:
#     Song_Name1A Artist_Name1 Last_Weekrank1 Peak_Rank1 Week_Onboard1
# 0    Last Night   Last Night              5          5             5
# 1    Last Night   Last Night              5          5             5
# 2    Last Night   Last Night              5          5             5
# 3       Flowers      Flowers              2          5             2
# 4     Kill Bill    Kill Bill              3          5             3
# ..          ...          ...            ...        ...           ...
# 97     Nonsense     Nonsense             75          5            75
# 98          AMG          AMG             80          5            80
# 99   Lift Me Up   Lift Me Up             65          5            65
# 100  You Didn't   You Didn't             78          5            78
# 101       10:35        10:35             81          5            81
#
# [102 rows x 5 columns]

# %% [markdown]
# 6. Scrape the details of Highest sellingnovels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get(" https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Book_Name=[]
Book_Author=[]
Book_volumesold=[]
Book_Publisher=[]
Book_Genre=[]

# %%
Book_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[2]')
for i in Book_tags:
    Name=i.text
    Book_Name.append(Name)
    
Book_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[3]')
for i in Book_tags:
    Author=i.text
    Book_Author.append(Author)    
    
Book_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[4]')
for i in Book_tags:
    volumesold=i.text
    Book_volumesold.append(volumesold)
    
Book_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[5]')
for i in Book_tags:
    Publisher=i.text
    Book_Publisher.append(Publisher) 
    
Book_tags=driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[5]')
for i in Book_tags:
    Genre=i.text
    Book_Genre.append(Genre)

# %%
print(len(Book_Name),len(Book_Author),len(Book_volumesold),len(Book_Publisher),len(Book_Genre))
# Out:
# 100 100 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Book_Name':Book_Name,'Author_Name':Book_Author,'VolumeSold':Book_volumesold,'Publisher':Book_Publisher,'Genre':Book_Genre})
df
# Out:
#                                             Book_Name       Author_Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    VolumeSold        Publisher            Genre
# 0   5,094,805       Transworld       Transworld
# ...

# %% [markdown]
# 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get("  https://www.imdb.com/list/ls095964455/ ")

# %%
Imdb_Name=[]
Imdb_Yearspan=[]
Imdb_Genre=[]
Imdb_Runtime=[]
Imdb_Ratings=[]
Imdb_Votes=[]

# %%
Imdb_tags=driver.find_elements(By.XPATH,'//div[@class="lister-list"][1]/div/div[2]/h3/a')
for i in Imdb_tags:
    Name=i.text
    Imdb_Name.append(Name)
    
    
Imdb_tags=driver.find_elements(By.XPATH,'//div[@class="lister-list"][1]/div/div[2]/h3/span[2]')
for i in Imdb_tags:
    Yearspan=i.text
    Imdb_Yearspan.append(Yearspan)
    
Imdb_tags=driver.find_elements(By.XPATH,'//div[@class="lister-list"][1]/div/div[2]/p[1]/span[5]')
for i in Imdb_tags:
    Genre=i.text
    Imdb_Genre.append(Genre) 
    
    
Imdb_tags=driver.find_elements(By.XPATH,'//div[@class="lister-list"][1]/div/div[2]/p[1]/span[3]')
for i in Imdb_tags:
    Runtime=i.text
    Imdb_Runtime.append(Runtime)
    
Imdb_tags=driver.find_elements(By.XPATH,'//div[@class="lister-list"][1]/div/div[2]/div[1]/div[1]/span[2]')
for i in Imdb_tags:
    Ratings=i.text
    Imdb_Ratings.append(Ratings)    
    
Imdb_tags=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[4]/span[2]')
for i in Imdb_tags:
    Votes=i.text
    Imdb_Votes.append(Votes)

# %%
print(len(Imdb_Name),len(Imdb_Yearspan),len(Imdb_Genre),len(Imdb_Runtime),len(Imdb_Ratings),len(Imdb_Votes))
# Out:
# 100 100 100 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Imdb_Name':Imdb_Name,'Imdb_Yearspan':Imdb_Yearspan,'Imdb_Genre':Imdb_Genre,'Imdb_Runtime':Imdb_Runtime,'Imdb_Ratings':Imdb_Ratings,'Imdb_Votes':Imdb_Votes})
df
# Out:
#                          Imdb_Name Imdb_Yearspan                Imdb_Genre  \
# 0                  Game of Thrones   (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things   (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead   (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why   (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100   (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...           ...                       ...
# 95                           Reign   (2013–2017)                     Drama
# 96  A Series of Unfortunate Events   (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds      (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series   (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House        (2018)    Drama, Horror, Mystery
#
#    Imdb_Runtime Imdb_Ratings Imdb_Votes
# ...

# %% [markdown]
# 8. Details of Datasetsfrom UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get(" https://archive.ics.uci.edu/ ")

# %%
searchADS=driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b')
searchADS.click()

# %%
Dataset_Name=[]
Dataset_Type=[]
Dataset_Task=[]
Dataset_AttributeType=[]
Dataset_NoofInstances=[]
Dataset_Noofattribute=[]
Dataset_YearNote=[]

# %%
India=driver.find_element(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[2]/p')

try:

    India.click()

except ElementNotInteractableException:

    driver.get(India.get_attribute('href'))

# %%
Dataset_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]/b')
for i in Dataset_tags:
    Name=i.text
    Dataset_Name.append(Name)
    
Dataset_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]/b')
for i in Dataset_tags:
    Type=i.text
    Dataset_Type.append(Type)

# %%
/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[2]/p

# %%
Dataset_tags=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[2]/p')
for i in Dataset_tags:
    Type=i.text
    Dataset_Type.append(Type)

# %%
len(Dataset_Type)
# Out:
# 1

# %% [markdown]
#  9. Scrape the details of Data science recruiters Url = https://www.naukri.com/hr-recruiters-consultants
# You have to find the following details:
# A) Name
# B) Designation
# C)Company
# D)Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver=webdriver.Chrome(r"D:\KN E D\DS\Internship\chromedriver_win32.zip\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/hr-recruiters-consultants ")

# %%
designation=driver.find_element(By.CLASS_NAME,"sugInp")
designation.send_keys('Data science')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
search.click()

# %%
Datascience_Name=[]
Datascience_Designation=[]
Datascience_Company=[]
Datascience_Skilltheyhire=[]
Datascience_Location=[]

# %%
Datascience_tags=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
for i in Datascience_tags[0:49]:
    Name=i.text
    Datascience_Name.append(Name)
    
Datascience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
for i in Datascience_tags[0:49]:
    Designation=i.text
    Datascience_Designation.append(Designation) 
    
Datascience_tags=driver.find_elements(By.XPATH,'//a[@class="ellipsis"][2]')
for i in Datascience_tags[0:49]:
    Company=i.text
    Datascience_Company.append(Company)    

Datascience_tags=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
for i in Datascience_tags[0:49]:
    Skilltheyhire=i.text
    Datascience_Skilltheyhire.append(Skilltheyhire)  
    
Datascience_tags=driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')
for i in Datascience_tags[0:49]:
    Location=i.text
    Datascience_Location.append(Location)

# %%
print(len(Datascience_Name),len(Datascience_Designation),len(Datascience_Company),len(Datascience_Skilltheyhire),len(Datascience_Location))
# Out:
# 49 49 49 49 49

# %%
import pandas as pd
df=pd.DataFrame({'Datascience_Name':Datascience_Name,'Datascience_Designation':Datascience_Designation,'Datascience_Company':Datascience_Company,'Datascience_Skilltheyhire':Datascience_Skilltheyhire,'Datascience_Location':Datascience_Location})
df
# Out:
#                                  Datascience_Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                                 Priyanka Akiri
# 15                                   Kapil Devang
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# ...
